# %% [markdown]
# ### Year Stats sheet status
#
# - Collected/loaded: yes
# - Reviewed for usefulness: yes
# - EDA needed: no, inspection only
# - Cleaning/prep completed: yes, removed fully empty 2010 and 2011 rows
# - Saved as separate prepared file: yes
# - Ready for SQL/Tableau: yes, as helper/reference data
# - Role: summary/reference dataset, not main analysis dataset

# %%
import pandas as pd

# %%
file_path = "../data/raw/public_ctwc_match_statistics.xlsx"

# %%
year_stats = pd.read_excel(file_path, sheet_name="Year Stats")
year_stats.head()
# Out:
#    Year  Total Games  Median Score  Transitions  Killscreens  Level 39s  \
# 0  2025        356.0     1028918.5        325.0        242.0       11.0
# 1  2024        354.0     1000380.0        318.0        217.0        8.0
# 2  2023        354.0      928482.5        304.0        189.0        6.0
# 3  2022        346.0      827740.5        279.0        140.0        9.0
# 4  2021        984.0      754400.0        777.0        281.0        2.0
#
#    Transition %  Killscreen %  Level 39%  Average Score   Average Win  \
# 0      0.912921      0.679775   0.030899    986860.0618  1.046003e+06
# 1      0.898305      0.612994   0.022599    938261.6384  9.883792e+05
# 2      0.858757      0.533898   0.016949    848542.2797  8.955919e+05
# 3      0.806358      0.404624   0.026012    772039.3988  8.156813e+05
# 4      0.789634      0.285569   0.002033    709364.6982  7.625043e+05
#
#    Average Loss  Median Lines  Average Lines  Median 19 Trans  Median 29 Trans
# ...

# %%
year_stats.shape
# Out:
# (16, 16)

# %%
year_stats.columns.tolist()
# Out:
# ['Year',
#  'Total Games',
#  'Median Score',
#  'Transitions',
#  'Killscreens',
#  'Level 39s',
#  'Transition %',
#  'Killscreen %',
#  'Level 39%',
#  'Average Score',
#  'Average Win',
#  'Average Loss',
#  'Median Lines',
#  'Average Lines',
#  'Median 19 Trans',
#  'Median 29 Trans']

# %%
year_stats.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             16 non-null     int64
#  1   Total Games      14 non-null     float64
#  2   Median Score     14 non-null     float64
#  3   Transitions      14 non-null     float64
#  4   Killscreens      14 non-null     float64
#  5   Level 39s        14 non-null     float64
#  6   Transition %     14 non-null     float64
#  7   Killscreen %     14 non-null     float64
#  8   Level 39%        14 non-null     float64
#  9   Average Score    14 non-null     float64
#  10  Average Win      14 non-null     float64
#  11  Average Loss     14 non-null     float64
#  12  Median Lines     14 non-null     float64
#  13  Average Lines    14 non-null     float64
#  14  Median 19 Trans  14 non-null     float64
#  15  Median 29 Trans  14 non-null     float64
# dtypes: float64(15), int64(1)
# ...

# %%
year_stats[year_stats.isna().any(axis=1)]
# Out:
#     Year  Total Games  Median Score  Transitions  Killscreens  Level 39s  \
# 14  2011          NaN           NaN          NaN          NaN        NaN
# 15  2010          NaN           NaN          NaN          NaN        NaN
#
#     Transition %  Killscreen %  Level 39%  Average Score  Average Win  \
# 14           NaN           NaN        NaN            NaN          NaN
# 15           NaN           NaN        NaN            NaN          NaN
#
#     Average Loss  Median Lines  Average Lines  Median 19 Trans  \
# 14           NaN           NaN            NaN              NaN
# 15           NaN           NaN            NaN              NaN
#
#     Median 29 Trans
# 14              NaN
# 15              NaN

# %%
year_stats_clean = year_stats.dropna(how="all", subset=year_stats.columns[1:]).copy()
year_stats_clean
# Out:
#     Year  Total Games  Median Score  Transitions  Killscreens  Level 39s  \
# 0   2025        356.0     1028918.5        325.0        242.0       11.0
# 1   2024        354.0     1000380.0        318.0        217.0        8.0
# 2   2023        354.0      928482.5        304.0        189.0        6.0
# 3   2022        346.0      827740.5        279.0        140.0        9.0
# 4   2021        984.0      754400.0        777.0        281.0        2.0
# 5   2020        940.0      603861.5        705.0        154.0        0.0
# 6   2019        256.0      472160.0        163.0         15.0        0.0
# 7   2018        174.0      466290.0        113.0         15.0        0.0
# 8   2017         98.0      454542.0         66.0          4.0        0.0
# 9   2016         90.0      475635.5         66.0          3.0        0.0
# 10  2015         90.0      439821.5         63.0          4.0        0.0
# 11  2014         50.0      463820.0         35.0          1.0        0.0
# ...

# %%
year_stats_clean.shape
# Out:
# (14, 16)

# %%
output_path = "../data/processed/ctwc_year_stats_cleaned.xlsx"
year_stats_clean.to_excel(output_path, index=False)

output_path
# Out:
# '../data/processed/ctwc_year_stats_cleaned.xlsx'

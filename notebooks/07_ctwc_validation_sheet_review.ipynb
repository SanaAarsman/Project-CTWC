# %% [markdown]
# ### Validation sheet status
#
# - Collected/loaded: yes
# - Reviewed for usefulness: yes
# - EDA needed: no, inspection only
# - Cleaning/prep completed: no
# - Saved as separate prepared file: no
# - Ready for SQL/Tableau: no
# - Role: not used; mixed validation/helper sheet with no practical value as a clean dataset

# %%
import pandas as pd

# %%
file_path = "../data/raw/public_ctwc_match_statistics.xlsx"

# %%
validation = pd.read_excel(file_path, sheet_name="Validation")
validation.head()
# Out:
#       Years         Players Country Code        Country Unique Countries  \
# 0  Lifetime             All          All            All              All
# 1      2025  Adam Cornelius          USA  United States    United States
# 2      2024         AdamMts          POL         Poland           Poland
# 3      2023     adudeabides          USA  United States   United Kingdom
# 4      2022       Alex Kerr          USA  United States        Australia
#
#    Unnamed: 5 Sorted Countries  Unnamed: 7
# 0         NaN              All         NaN
# 1       129.0    United States       129.0
# 2         1.0           Canada        11.0
# 3         8.0   United Kingdom         8.0
# 4         2.0            Japan         4.0

# %%
validation.shape
# Out:
# (185, 8)

# %%
validation.columns.tolist()
# Out:
# ['Years',
#  'Players',
#  'Country Code',
#  'Country',
#  'Unique Countries',
#  'Unnamed: 5',
#  'Sorted Countries',
#  'Unnamed: 7']

# %%
validation.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Years             17 non-null     object
#  1   Players           185 non-null    str
#  2   Country Code      185 non-null    str
#  3   Country           185 non-null    str
#  4   Unique Countries  30 non-null     str
#  5   Unnamed: 5        40 non-null     float64
#  6   Sorted Countries  30 non-null     str
#  7   Unnamed: 7        40 non-null     float64
# dtypes: float64(2), object(1), str(5)
# memory usage: 11.7+ KB

# %%
validation["Players"].nunique()
# Out:
# 185

# %%
validation["Players"].notna().sum()
# Out:
# np.int64(185)

# %%
validation.head(20)
# Out:
#        Years         Players Country Code         Country Unique Countries  \
# 0   Lifetime             All          All             All              All
# 1       2025  Adam Cornelius          USA   United States    United States
# 2       2024         AdamMts          POL          Poland           Poland
# 3       2023     adudeabides          USA   United States   United Kingdom
# 4       2022       Alex Kerr          USA   United States        Australia
# 5       2021          Alex T          USA   United States          Romania
# 6       2020          Alex_H          GBR  United Kingdom          Germany
# 7       2019       AnfonyHoe          AUS       Australia          Finland
# 8       2018       Anomalous          USA   United States           Canada
# 9       2017     AnselTetris          USA   United States      Switzerland
# 10      2016       armstrong          USA   United States            Japan
# ...

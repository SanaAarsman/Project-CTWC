# %% [markdown]
# ### Custom Leaderboard Stats sheet status
#
# - Collected/loaded: yes
# - Reviewed for usefulness: yes
# - EDA needed: no, inspection only
# - Cleaning/prep completed: no
# - Saved as separate prepared file: no
# - Ready for SQL/Tableau: no
# - Role: not used; sheet structure is not usable for the project

# %%
import pandas as pd

# %%
file_path = "../data/raw/public_ctwc_match_statistics.xlsx"

# %%
custom_leaderboard_stats = pd.read_excel(file_path, sheet_name="Custom Leaderboard Stats")
custom_leaderboard_stats.head()
# Out:
#           Player  Fair Median Post Post  Fair Median Post Post.1  Games  \
# 0          Jonas                    NaN                      NaN      0
# 1     Harry Hong                    NaN                      NaN      0
# 2  Eli Markstrom                    NaN                      NaN      0
# 3   Robin Mihara                    NaN                      NaN      0
# 4     Ben Mullen                    NaN                      NaN      0
#
#    Maxouts  Rollovers  Winning %  Fair Median Score  High Range  Low Range  \
# 0      NaN        NaN        NaN                NaN         NaN        NaN
# 1      NaN        NaN        NaN                NaN         NaN        NaN
# 2      NaN        NaN        NaN                NaN         NaN        NaN
# 3      NaN        NaN        NaN                NaN         NaN        NaN
# 4      NaN        NaN        NaN                NaN         NaN        NaN
#
#    ...  Fair Median Post Post.2  Fair 19 %  Fair 29 %  Fair 38 %  High Score  \
# 0  ...                      NaN        NaN        NaN        NaN         NaN
# 1  ...                      NaN        NaN        NaN        NaN         NaN
# 2  ...                      NaN        NaN        NaN        NaN         NaN
# 3  ...                      NaN        NaN        NaN        NaN         NaN
# 4  ...                      NaN        NaN        NaN        NaN         NaN
#
#    Median Score  Upper Quartile  Lower Quartile  Median Post  Median Post Post
# 0           NaN             NaN             NaN          NaN               NaN
# 1           NaN             NaN             NaN          NaN               NaN
# 2           NaN             NaN             NaN          NaN               NaN
# 3           NaN             NaN             NaN          NaN               NaN
# 4           NaN             NaN             NaN          NaN               NaN
#
# [5 rows x 25 columns]

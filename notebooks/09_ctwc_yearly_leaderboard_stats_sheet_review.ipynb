# %% [markdown]
# ### Yearly Leaderboard Stats sheet status
#
# - Collected/loaded: yes
# - Reviewed for usefulness: yes
# - EDA needed: no, inspection only
# - Cleaning/prep completed: no
# - Saved as separate prepared file: no
# - Ready for SQL/Tableau: no
# - Role: not used; sheet does not contain a usable year dimension and does not support the main project red thread

# %%
import pandas as pd

# %%
file_path = "../data/raw/public_ctwc_match_statistics.xlsx"

# %%
yearly_leaderboard_stats = pd.read_excel(file_path, sheet_name="Yearly Leaderboard Stats")
yearly_leaderboard_stats.head()
# Out:
#           Player  Total Games  Total Maxouts  Winning Percentage  \
# 0          Jonas            3              0            0.333333
# 1     Harry Hong            3              0            0.333333
# 2  Eli Markstrom            0              0                 NaN
# 3   Robin Mihara            4              0            0.500000
# 4     Ben Mullen            5              0            0.400000
#
#    Fair Median Score  High Range  Low Range  Fair Median 19 Trans  \
# 0           210900.0   419350.00   177080.0              210900.0
# 1           664061.0   668787.50   592521.0              510841.0
# 2                NaN         NaN        NaN                   NaN
# 3           444609.0   518672.50   425058.5              377830.5
# 4           507040.0   609472.25   482400.0              459480.0
#
#    Fair Median 29 Trans  Fair Median Post  Fair 19%  Fair 29%  Fair 38%  \
# 0                   NaN          117740.0  0.333333       0.0       0.0
# ...

# %%
yearly_leaderboard_stats.shape
# Out:
# (184, 19)

# %%
yearly_leaderboard_stats.columns.tolist()
# Out:
# ['Player',
#  'Total Games',
#  'Total Maxouts',
#  'Winning Percentage',
#  'Fair Median Score',
#  'High Range',
#  'Low Range',
#  'Fair Median 19 Trans',
#  'Fair Median 29 Trans',
#  'Fair Median Post',
#  'Fair 19%',
#  'Fair 29%',
#  'Fair 38%',
#  'Median Score',
#  'Upper Quartile',
#  'Lower Quartile',
#  'Median 19 Trans',
#  'Median 29 Trans',
#  'Median Post']

# %%
yearly_leaderboard_stats.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 184 entries, 0 to 183
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Player                184 non-null    str
#  1   Total Games           184 non-null    int64
#  2   Total Maxouts         184 non-null    int64
#  3   Winning Percentage    48 non-null     float64
#  4   Fair Median Score     48 non-null     float64
#  5   High Range            48 non-null     float64
#  6   Low Range             48 non-null     float64
#  7   Fair Median 19 Trans  44 non-null     float64
#  8   Fair Median 29 Trans  11 non-null     float64
#  9   Fair Median Post      44 non-null     float64
#  10  Fair 19%              48 non-null     float64
#  11  Fair 29%              48 non-null     float64
#  12  Fair 38%              48 non-null     float64
#  13  Median Score          48 non-null     float64
#  14  Upper Quartile        48 non-null     float64
# ...

# %% [markdown]
# ### Countries sheet status
#
# - Collected/loaded: yes
# - Reviewed for usefulness: yes
# - EDA needed: no, inspection only
# - Cleaning/prep completed: yes, dropped fully empty `Flag` column
# - Saved as separate prepared file: yes
# - Ready for SQL/Tableau: yes, as helper lookup data
# - Role: helper dataset for mapping country codes to country names

# %%
import pandas as pd

# %%
file_path = "../data/raw/public_ctwc_match_statistics.xlsx"

# %%
countries = pd.read_excel(file_path, sheet_name="Countries")
countries.head()
# Out:
#   Code         Name  Flag
# 0  AFG  Afghanistan   NaN
# 1  ALB      Albania   NaN
# 2  ALG      Algeria   NaN
# 3  AND      Andorra   NaN
# 4  ANG       Angola   NaN

# %%
countries.shape
# Out:
# (213, 3)

# %%
countries.columns.tolist()
# Out:
# ['Code', 'Name', 'Flag']

# %%
countries.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Code    213 non-null    str
#  1   Name    212 non-null    str
#  2   Flag    0 non-null      float64
# dtypes: float64(1), str(2)
# memory usage: 5.1 KB

# %%
countries_clean = countries.drop(columns=["Flag"]).copy()
countries_clean.head()
# Out:
#   Code         Name
# 0  AFG  Afghanistan
# 1  ALB      Albania
# 2  ALG      Algeria
# 3  AND      Andorra
# 4  ANG       Angola

# %%
countries_clean.shape
# Out:
# (213, 2)

# %%
output_path = "../data/processed/ctwc_countries_cleaned.xlsx"
countries_clean.to_excel(output_path, index=False)

output_path
# Out:
# '../data/processed/ctwc_countries_cleaned.xlsx'

# %%
countries_clean.columns.tolist()
# Out:
# ['Code', 'Name']

# %% [markdown]
# ### Player Statistics Games sheet status
#
# - Collected/loaded: yes
# - Reviewed for usefulness: yes
# - EDA needed: no, inspection only
# - Cleaning/prep completed: no
# - Saved as separate prepared file: no
# - Ready for SQL/Tableau: no
# - Role: not used; duplicate-like sheet with no practical added value for this project

# %%
import pandas as pd

# %%
file_path = "../data/raw/public_ctwc_match_statistics.xlsx"

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)

# %%
player_stats_games = pd.read_excel(file_path, sheet_name="Player Statistics Games")
player_stats_games.head()
# Out:
#        Player  Game Playstyle Won?  Final Score  Total Lines  No M Score  \
# 0       Jonas     1       DAS  Yes       530034        195.0    339042.0
# 1  Harry Hong     1       DAS   No       302118        133.0         NaN
# 2       Jonas     2       DAS  Yes       544534        245.0    542531.0
# 3  Harry Hong     2       DAS   No       517590        227.0         NaN
# 4       Jonas     1       DAS  Yes       164153         55.0    164153.0
#
#    No M Lines  19 Trans  19 L Start  29 Trans  29 L Start  39 Trans  \
# 0       135.0  522034.0       190.0       NaN         NaN       NaN
# 1         NaN       NaN         NaN       NaN         NaN       NaN
# 2       243.0  443999.0       192.0       NaN         NaN       NaN
# 3         NaN  483111.0       191.0       NaN         NaN       NaN
# 4        55.0       NaN         NaN       NaN         NaN       NaN
#
#    39 L Start  Topout Type  Level  Cap SPS  Year  Event   Round  \
# ...

# %%
player_stats_games.shape
# Out:
# (4202, 26)

# %%
player_stats_games.columns.tolist()
# Out:
# ['Player',
#  'Game',
#  'Playstyle',
#  'Won?',
#  'Final Score',
#  'Total Lines',
#  'No M Score',
#  'No M Lines',
#  '19 Trans',
#  '19 L Start',
#  '29 Trans',
#  '29 L Start',
#  '39 Trans',
#  '39 L Start',
#  'Topout Type',
#  'Level',
#  'Cap',
#  'SPS',
#  'Year',
#  'Event',
#  'Round',
#  'Game Link',
#  'Unnamed: 22',
#  'Unnamed: 23',
#  'Post',
#  'Post Post']

# %%
player_stats_games.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4202 entries, 0 to 4201
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Player       4202 non-null   str
#  1   Game         4202 non-null   int64
#  2   Playstyle    4202 non-null   str
#  3   Won?         4202 non-null   str
#  4   Final Score  4202 non-null   int64
#  5   Total Lines  4184 non-null   float64
#  6   No M Score   2073 non-null   float64
#  7   No M Lines   2068 non-null   float64
#  8   19 Trans     3283 non-null   float64
#  9   19 L Start   3281 non-null   float64
#  10  29 Trans     1245 non-null   float64
#  11  29 L Start   1245 non-null   float64
#  12  39 Trans     32 non-null     float64
#  13  39 L Start   32 non-null     float64
#  14  Topout Type  4201 non-null   str
#  15  Level        4202 non-null   int64
#  16  Cap          1064 non-null   str
#  17  SPS          4202 non-null   str
#  18  Year         4202 non-null   int64
# ...
